# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Numpy
#
# * n-dimensional array: a collection of elements

# %%
a_py = [10,20,40,23, 2323, 121,4322]

# %%
type(a_py)
# Out:
# list

# %%
b_np = np.array([2, 34,12, 54,655])

# %%
type(b_np)
# Out:
# numpy.ndarray

# %%
a_py
# Out:
# [10, 20, 40, 23, 2323, 121, 4322]

# %%
b_np
# Out:
# array([  2,  34,  12,  54, 655])

# %% [markdown]
# ### Q: muliply all the numbers by 10

# %%
arr=[]
for i in a_py:
  arr.append(i * 10)
arr
# Out:
# [100, 200, 400, 230, 23230, 1210, 43220]

# %%
list(map(lambda i: i*10, a_py))
# Out:
# [100, 200, 400, 230, 23230, 1210, 43220]

# %%
[i*10 for i in a_py]
# Out:
# [100, 200, 400, 230, 23230, 1210, 43220]

# %%
b_np * 10
# much better performance an smaller memory footprint
# Out:
# array([  20,  340,  120,  540, 6550])

# %% [markdown]
# ### trade off : numpy arrays contain only one data type

# %%
c_np = np.array([1,3.,4])
#implicit upcasting :

# %%
c_np
# Out:
# array([1., 3., 4.])

# %%
c_np.dtype
# Out:
# dtype('float64')

# %%
b_np.dtype
# Out:
# dtype('int64')
